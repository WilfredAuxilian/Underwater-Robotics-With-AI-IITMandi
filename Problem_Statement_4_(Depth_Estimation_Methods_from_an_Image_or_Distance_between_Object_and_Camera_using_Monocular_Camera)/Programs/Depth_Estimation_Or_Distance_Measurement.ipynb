# %% [markdown]
# ****Distance Measurement From Camera And Seabed****

# %% [markdown]
# **1) Pinhole Camera Method**

# %%
import cv2
import numpy as np

                                                                                        # Camera parameters for this method
KNOWN_OBJECT_WIDTH = 0.5                                                                # a known seabed feature size, measured in meters
FOCAL_LENGTH = 800                                                                      # calibrate your camera based on pixel size, measured in pixels

def calculate_distance(pixel_width):
    if pixel_width > 0:
        distance = (KNOWN_OBJECT_WIDTH * FOCAL_LENGTH) / pixel_width
        return distance
    return None

def detect_seabed_feature(frame):
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)                                      # Convertion into grayscale
    blurred = cv2.GaussianBlur(gray, (5, 5), 0)                                         # Applying blur to reduce noise
    edges = cv2.Canny(blurred, 50, 150)                                                 # Edge detection using Canny Filter
    contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)   # Finding contours

    if contours:
        largest_contour = max(contours, key=cv2.contourArea)                            # Getting the largest contour among other
        rect = cv2.minAreaRect(largest_contour)                                         # Get the width of the bounding rectangle
        pixel_width = rect[1][0]                                           # Width in pixels which gets converted into pixel width and returns as result
        return pixel_width
    return 0

cap = cv2.VideoCapture(0)                                                               #  Open the camera and 0 is the default camera index

if not cap.isOpened():
    print("Error: Could not open camera.")
else:
    ret, frame = cap.read()                                                             # Capture a single frame
    if ret:
        pixel_width = detect_seabed_feature(frame)                                      # Detect seabed feature
        
        distance = calculate_distance(pixel_width)                                      # pixel width goes in Calculate distance function
        
        if distance:                                                                    #  Display results
            print(f"Pixel Width: {pixel_width:.2f} pixels")
            print(f"Distance to Seabed: {distance:.2f} meters")
            
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)                              # Draw the contour on the frame for visualization
            edges = cv2.Canny(gray, 50, 150)
            contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
            if contours:
                largest_contour = max(contours, key=cv2.contourArea)
                cv2.drawContours(frame, [largest_contour], -1, (0, 255, 0), 2)
                cv2.putText(frame, f"Distance: {distance:.2f} m", (10, 30),
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
                
                cv2.imshow("Camera Feed", frame)
                cv2.waitKey(0) 
        else:
            print("No valid object detected for distance calculation.")
    else:
        print("Error: Could not read frame.")
    
    cap.release()
    cv2.destroyAllWindows()
# Out:
# Pixel Width: 25.18 pixels
# Distance to Seabed: 15.89 meters

# %% [markdown]
# **2) MiDAS - AI Based Monocular Depth Estimation**

# %% [markdown]
# **It shows frame per second and Relative Depth Value. So Larger Values = Farther Objects , Smaller Values = Closer Objects. It is just a scaled number without units**

# %%
# !pip install torch torchvision opencv-python timm
# Out:
# Requirement already satisfied: torch in c:\anaconda\lib\site-packages (2.6.0)
# Requirement already satisfied: torchvision in c:\anaconda\lib\site-packages (0.21.0)
# Requirement already satisfied: opencv-python in c:\anaconda\lib\site-packages (4.10.0.84)
# Requirement already satisfied: timm in c:\anaconda\lib\site-packages (1.0.15)
# Requirement already satisfied: filelock in c:\anaconda\lib\site-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\anaconda\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in c:\anaconda\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\anaconda\lib\site-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in c:\anaconda\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in c:\anaconda\lib\site-packages (from torch) (75.8.2)
# Requirement already satisfied: sympy==1.13.1 in c:\anaconda\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\anaconda\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in c:\anaconda\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\anaconda\lib\site-packages (from torchvision) (10.4.0)
# Requirement already satisfied: pyyaml in c:\anaconda\lib\site-packages (from timm) (6.0.1)
# Requirement already satisfied: huggingface_hub in c:\anaconda\lib\site-packages (from timm) (0.33.0)
# Requirement already satisfied: safetensors in c:\anaconda\lib\site-packages (from timm) (0.5.3)
# Requirement already satisfied: packaging>=20.9 in c:\anaconda\lib\site-packages (from huggingface_hub->timm) (24.1)
# Requirement already satisfied: requests in c:\anaconda\lib\site-packages (from huggingface_hub->timm) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\anaconda\lib\site-packages (from huggingface_hub->timm) (4.66.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\anaconda\lib\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: colorama in c:\anaconda\lib\site-packages (from tqdm>=4.42.1->huggingface_hub->timm) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\anaconda\lib\site-packages (from requests->huggingface_hub->timm) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda\lib\site-packages (from requests->huggingface_hub->timm) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconda\lib\site-packages (from requests->huggingface_hub->timm) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda\lib\site-packages (from requests->huggingface_hub->timm) (2024.8.30)
# WARNING: Ignoring invalid distribution ~orch (C:\Anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~orch (C:\Anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~orch (C:\Anaconda\Lib\site-packages)

# %%
import cv2
import torch
import numpy as np
import time

midas = torch.hub.load("intel-isl/MiDaS", "MiDaS_small", trust_repo=True)                     # Loading MiDaS model
midas.eval()

midas_transforms = torch.hub.load("intel-isl/MiDaS", "transforms", trust_repo=True)           # Loading transforms
transform = midas_transforms.small_transform

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")                         # Move model to device
midas.to(device)

cap = cv2.VideoCapture(0) # Start webcam
if not cap.isOpened():
    print("Cannot Open Webcam")
    exit()

print("Webcam and MiDaS initialized. Press 'q' to quit.")

prev_time = time.time()

while True:
    ret, frame = cap.read()
    if not ret:
        print("Failed to grab frame")
        break

    img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)                                               # Convert BGR to RGB

    input_image = transform(img).to(device)                                                    # Apply MiDaS transform
    input_batch = input_image                                                                  # already batched

    with torch.no_grad():                                                                      # Depth inference
        prediction = midas(input_batch)
        prediction = torch.nn.functional.interpolate(
            prediction.unsqueeze(1),
            size=img.shape[:2],
            mode="bicubic",
            align_corners=False,
        ).squeeze()

        depth_map = prediction.cpu().numpy()

    depth_min = depth_map.min()                                                                # Normalize depth map for visualization
    depth_max = depth_map.max()
    depth_vis = (255 * (depth_map - depth_min) / (depth_max - depth_min)).astype(np.uint8)
    depth_colormap = cv2.applyColorMap(depth_vis, cv2.COLORMAP_MAGMA)

    current_time = time.time()                                                                  # Calculate FPS
    fps = 1.0 / (current_time - prev_time)
    prev_time = current_time

    cv2.putText(frame, f"FPS: {fps:.2f}", (10, 30),                                             # Draw FPS on original frame
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

    h, w = depth_map.shape                                                                      # Draw depth value at center of depth map
    center_x, center_y = w // 2, h // 2
    center_depth = depth_map[center_y, center_x]
    cv2.putText(depth_colormap, f"Depth: {center_depth:.2f}", (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)

    combined = np.hstack((frame, depth_colormap))                                             
    cv2.imshow("Webcam + MiDaS Depth", combined)

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Using cache found in C:\Users\Wilfred Auxilian/.cache\torch\hub\intel-isl_MiDaS_master
# C:\Anaconda\Lib\site-packages\timm\models\layers\__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Using cache found in C:\Users\Wilfred Auxilian/.cache\torch\hub\rwightman_gen-efficientnet-pytorch_master
# Loading weights:  None
# Using cache found in C:\Users\Wilfred Auxilian/.cache\torch\hub\intel-isl_MiDaS_master
# Webcam and MiDaS initialized. Press 'q' to quit.

# %% [markdown]
# **3) Depth from motion via Optical Flow**

# %% [markdown]
# **It captures two continuos frames and compute optical flow between them. It uses Flow Magnitude (Larger Flow = Closer Object).**

# %%
import cv2
import numpy as np
import time

cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Cannot open webcam")
    exit()

ret, prev_frame = cap.read()
prev_gray = cv2.cvtColor(prev_frame, cv2.COLOR_BGR2GRAY)

print("Starting video. Press 'q' to quit.")

while True:
    start = time.time()
    ret, frame = cap.read()
    if not ret:
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    flow = cv2.calcOpticalFlowFarneback(prev_gray, gray, None,
                                        pyr_scale=0.5, levels=3, winsize=15,
                                        iterations=3, poly_n=5, poly_sigma=1.2, flags=0)

    mag, ang = cv2.cartToPolar(flow[..., 0], flow[..., 1])
    mag_norm = cv2.normalize(mag, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
    depth_heatmap = cv2.applyColorMap(255 - mag_norm, cv2.COLORMAP_INFERNO)

    fps = 1.0 / (time.time() - start)
    cv2.putText(frame, f"FPS: {fps:.2f}", (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

    combo = np.hstack((frame, depth_heatmap))
    cv2.imshow("Motion-Based Depth Proxy", combo)

    prev_gray = gray.copy()

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Starting video. Press 'q' to quit.

# %%
import cv2
import numpy as np
import time

cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Cannot open webcam")
    exit()

ret, prev_frame = cap.read()                                                        # Read the first frame
prev_gray = cv2.cvtColor(prev_frame, cv2.COLOR_BGR2GRAY)

print("Depth from Motion running... Press 'q' to quit.")

while True:
    start_time = time.time()

    ret, frame = cap.read()                                                         # Read the next frame
    if not ret:
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    flow = cv2.calcOpticalFlowFarneback(prev_gray, gray, None,                              # Compute optical flow
                                        pyr_scale=0.5, levels=3, winsize=15,
                                        iterations=3, poly_n=5, poly_sigma=1.2, flags=0)

    mag, ang = cv2.cartToPolar(flow[..., 0], flow[..., 1])                        # Flow magnitude as proxy for inverse depth (closer objects move more)

    inv_depth = 1 / (mag + 1e-5)                                                  # Normalize inverse magnitude to simulate depth
    inv_depth_normalized = cv2.normalize(inv_depth, None, 0, 255, cv2.NORM_MINMAX)
    depth_display = inv_depth_normalized.astype(np.uint8)

    depth_colored = cv2.applyColorMap(depth_display, cv2.COLORMAP_INFERNO)        # Apply colormap for visualization

    fps = 1.0 / (time.time() - start_time)                                        # FPS Counter
    cv2.putText(frame, f"FPS: {fps:.2f}", (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

    h, w = mag.shape                                                              # Display example depth value at the center
    depth_val = inv_depth[int(h/2), int(w/2)]
    cv2.putText(depth_colored, f"Depth(center): {depth_val:.2f} (relative units)", (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)

    combined = np.hstack((frame, depth_colored))                                  # Combine original frame and depth map side-by-side

    cv2.imshow("Depth from Motion (Monocular)", combined)

    prev_gray = gray.copy()

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Depth from Motion running... Press 'q' to quit.

# %% [markdown]
# **4)Structure from Motion (SFM)**

# %% [markdown]
# **It process the live frames and detects and matches features among them, triangulates 3D points and estimate avg depth of those 3D Points**

# %%
import cv2
import numpy as np

                                                                       # Camera intrinsic parameters (calibrate your camera or use approximate values)
K = np.array([[800, 0, 320], 
              [0, 800, 240],
              [0, 0, 1]], dtype=np.float32)

def extract_features(img):                                             # Detect ORB features and compute descriptors.
    orb = cv2.ORB_create()
    keypoints, descriptors = orb.detectAndCompute(img, None)
    return keypoints, descriptors

def match_features(des1, des2):
    bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)              # Match features between two frames using BFMatcher.
    matches = bf.match(des1, des2)
    matches = sorted(matches, key=lambda x: x.distance)
    return matches

def estimate_motion(pts1, pts2, K):                                    # Estimate essential matrix and recover camera pose.
    E, mask = cv2.findEssentialMat(pts1, pts2, K, method=cv2.RANSAC, prob=0.999, threshold=1.0)
    _, R, t, mask = cv2.recoverPose(E, pts1, pts2, K, mask=mask)
    return R, t, mask

def triangulate_points(pts1, pts2, K, R, t):                           # Triangulate 3D points from matched 2D points.
    pts1 = np.array(pts1, dtype=np.float32).reshape(-1, 2)
    pts2 = np.array(pts2, dtype=np.float32).reshape(-1, 2)

    P1 = np.hstack((K, np.zeros((3, 1))))                               # Projection matrices
    P2 = np.hstack((K @ R, K @ t.reshape(3, 1)))

    pts1 = pts1.T                                                       # Transpose points to 2xN format for cv2.triangulatePoints
    pts2 = pts2.T  

    points_4d = cv2.triangulatePoints(P1, P2, pts1, pts2)               # Triangulate
    points_3d = points_4d[:3] / points_4d[3]                            # Convert to homogeneous coordinates
    return points_3d.T  

def main():
    cap = cv2.VideoCapture(0)
    if not cap.isOpened():
        print("Error: Could not open camera.")
        return

    prev_img = None                                                     # Variables to store previous frame data
    prev_kp = None
    prev_des = None

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        
        kp, des = extract_features(gray)

        if prev_img is not None and prev_des is not None:
            matches = match_features(prev_des, des)                                                         # Match features with previous frame
            if len(matches) > 10: 
                pts1 = np.float32([prev_kp[m.queryIdx].pt for m in matches]).reshape(-1, 2)
                pts2 = np.float32([kp[m.trainIdx].pt for m in matches]).reshape(-1, 2)

                R, t, mask = estimate_motion(pts1, pts2, K)                                                 # Estimate camera motion

                mask = mask.ravel() > 0                                                                     # Filter points using mask
                if np.sum(mask) > 0: 
                    points_3d = triangulate_points(pts1[mask], pts2[mask], K, R, t)                         # Triangulate 3D points

                    depths = points_3d[:, 2]                                                                # Compute depth (z-coordinate)
                    valid_depths = depths[depths > 0] 
                    if len(valid_depths) > 0:
                        avg_depth = np.mean(valid_depths)
                        print(f"Average depth: {avg_depth:.2f} meters")

                    img_matches = cv2.drawMatches(prev_img, prev_kp, gray, kp, matches[:50], None,          # Draw matches
                                                flags=cv2.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)
                    cv2.imshow('Feature Matches', img_matches)

        prev_img = gray.copy()                                                                              # Update previous frame data
        prev_kp = kp
        prev_des = des

        cv2.imshow('Live Feed', frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    main()
# Out:
#
# Average depth: 30.38 meters
# Average depth: 27.94 meters
# Average depth: 25.42 meters
# Average depth: 32.38 meters
# Average depth: 28.73 meters
# Average depth: 44.25 meters
# Average depth: 28.14 meters
# Average depth: 41.38 meters
# Average depth: 31.42 meters
# Average depth: 21.70 meters
# Average depth: 26.58 meters
# Average depth: 15.92 meters
# Average depth: 19.52 meters
# Average depth: 47.67 meters
# Average depth: 28.97 meters
# Average depth: 25.31 meters
# Average depth: 38.43 meters
# Average depth: 43.25 meters
# Average depth: 44.05 meters
# Average depth: 26.28 meters
# Average depth: 23.00 meters
# Average depth: 24.17 meters
# Average depth: 29.83 meters
# Average depth: 48.63 meters
# Average depth: 31.93 meters
# Average depth: 32.83 meters
# Average depth: 35.23 meters
# Average depth: 19.15 meters
# Average depth: 27.00 meters
# Average depth: 33.33 meters
# Average depth: 20.95 meters
# Average depth: 35.04 meters
# Average depth: 37.58 meters
# Average depth: 31.30 meters
# Average depth: 26.56 meters
# Average depth: 32.31 meters
# Average depth: 35.72 meters
# Average depth: 40.62 meters
# Average depth: 7.98 meters
# Average depth: 14.82 meters
# Average depth: 24.61 meters
# Average depth: 39.03 meters
# Average depth: 20.79 meters
# Average depth: 19.88 meters
# Average depth: 25.92 meters
# Average depth: 15.15 meters
# Average depth: 28.13 meters
# Average depth: 18.10 meters
# Average depth: 38.12 meters
# Average depth: 30.14 meters
# Average depth: 19.93 meters
# Average depth: 29.61 meters
# Average depth: 32.36 meters
# Average depth: 23.04 meters
# Average depth: 24.92 meters
# Average depth: 24.14 meters
# Average depth: 27.42 meters
# Average depth: 37.68 meters
# Average depth: 27.93 meters
# Average depth: 33.54 meters
# Average depth: 17.98 meters
# Average depth: 24.44 meters
# Average depth: 27.22 meters
# Average depth: 20.41 meters
# Average depth: 30.68 meters
# Average depth: 32.12 meters
# Average depth: 18.71 meters
# Average depth: 25.06 meters
# Average depth: 42.97 meters
# Average depth: 39.69 meters
# Average depth: 32.36 meters
# Average depth: 20.22 meters
# Average depth: 33.21 meters
# Average depth: 36.76 meters
# Average depth: 28.98 meters
# Average depth: 34.91 meters
# Average depth: 23.05 meters
# Average depth: 30.82 meters
# Average depth: 21.10 meters
# Average depth: 32.69 meters
# Average depth: 20.00 meters
# Average depth: 37.10 meters
# Average depth: 27.03 meters
# Average depth: 31.95 meters

# %% [markdown]
# **5)Intensity Based Depth Estimation**

# %% [markdown]
# **Light intensity especially in the red channel decreases with depth due to absorption and scattering. By analyzing color channel attenuation (red diminishes faster than blue/green), we can estimate relative depth. This method uses a single frame and is robust to low-texture scenes.**

# %%
import cv2
import numpy as np

def preprocess_underwater_image(image):                                  # Enhance contrast and reduce haze for underwater images.
    lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8, 8))
    l = clahe.apply(l)
    lab = cv2.merge((l, a, b))
    return cv2.cvtColor(lab, cv2.COLOR_LAB2BGR)

def estimate_depth_from_intensity(image):                                 # Estimate relative depth based on red-to-blue channel ratio.
    b, g, r = cv2.split(image)
    blue = b.astype(np.float32) + 1e-6
    red = r.astype(np.float32) + 1e-6
    ratio = blue / red  
    depth_map = cv2.normalize(ratio, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
    depth_indicator = np.mean(ratio)
    return depth_map, depth_indicator

def main():
    cap = cv2.VideoCapture(0) 
    if not cap.isOpened():
        print("Error: Could not open camera.")
        return

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        frame = preprocess_underwater_image(frame)

        depth_map, depth_indicator = estimate_depth_from_intensity(frame)                       # Estimate depth from intensity
        print(f"Relative depth indicator: {depth_indicator:.2f} (higher = farther)")

        cv2.imshow('Live Feed', frame)
        cv2.imshow('Depth Map', depth_map)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    main()
# Out:
# Relative depth indicator: 392866.28 (higher = farther)
# Relative depth indicator: 19018.16 (higher = farther)
# Relative depth indicator: 11013.56 (higher = farther)
# Relative depth indicator: 15629.43 (higher = farther)
# Relative depth indicator: 11472.49 (higher = farther)
# Relative depth indicator: 5082.50 (higher = farther)
# Relative depth indicator: 3119.58 (higher = farther)
# Relative depth indicator: 3760.85 (higher = farther)
# Relative depth indicator: 4418.38 (higher = farther)
# Relative depth indicator: 1657.95 (higher = farther)
# Relative depth indicator: 5248.44 (higher = farther)
# Relative depth indicator: 1605.85 (higher = farther)
# Relative depth indicator: 1094.77 (higher = farther)
# Relative depth indicator: 749.72 (higher = farther)
# Relative depth indicator: 749.72 (higher = farther)
# Relative depth indicator: 639.04 (higher = farther)
# Relative depth indicator: 769.25 (higher = farther)
# Relative depth indicator: 707.41 (higher = farther)
# Relative depth indicator: 2217.82 (higher = farther)
# Relative depth indicator: 228.89 (higher = farther)
# Relative depth indicator: 202.85 (higher = farther)
# Relative depth indicator: 320.03 (higher = farther)
# Relative depth indicator: 1085.01 (higher = farther)
# Relative depth indicator: 127.98 (higher = farther)
# Relative depth indicator: 127.98 (higher = farther)
# Relative depth indicator: 866.91 (higher = farther)
# Relative depth indicator: 671.59 (higher = farther)
# Relative depth indicator: 486.05 (higher = farther)
# Relative depth indicator: 401.42 (higher = farther)
# Relative depth indicator: 2247.12 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 183.31 (higher = farther)
# Relative depth indicator: 209.36 (higher = farther)
# Relative depth indicator: 49.85 (higher = farther)
# Relative depth indicator: 49.85 (higher = farther)
# Relative depth indicator: 788.78 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 1817.43 (higher = farther)
# Relative depth indicator: 427.46 (higher = farther)
# Relative depth indicator: 687.87 (higher = farther)
# Relative depth indicator: 14.03 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 824.59 (higher = farther)
# Relative depth indicator: 2631.23 (higher = farther)
# Relative depth indicator: 2631.23 (higher = farther)
# Relative depth indicator: 710.66 (higher = farther)
# Relative depth indicator: 1459.36 (higher = farther)
# Relative depth indicator: 674.85 (higher = farther)
# Relative depth indicator: 997.11 (higher = farther)
# Relative depth indicator: 720.42 (higher = farther)
# Relative depth indicator: 798.54 (higher = farther)
# Relative depth indicator: 1472.37 (higher = farther)
# Relative depth indicator: 473.02 (higher = farther)
# Relative depth indicator: 167.03 (higher = farther)
# Relative depth indicator: 167.03 (higher = farther)
# Relative depth indicator: 469.77 (higher = farther)
# Relative depth indicator: 199.59 (higher = farther)
# Relative depth indicator: 1667.68 (higher = farther)
# Relative depth indicator: 554.41 (higher = farther)
# Relative depth indicator: 1543.99 (higher = farther)
# Relative depth indicator: 1026.41 (higher = farther)
# Relative depth indicator: 1003.62 (higher = farther)
# Relative depth indicator: 694.38 (higher = farther)
# Relative depth indicator: 1504.93 (higher = farther)
# Relative depth indicator: 336.31 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 186.57 (higher = farther)
# Relative depth indicator: 365.60 (higher = farther)
# Relative depth indicator: 580.44 (higher = farther)
# Relative depth indicator: 160.51 (higher = farther)
# Relative depth indicator: 297.20 (higher = farther)
# Relative depth indicator: 619.45 (higher = farther)
# Relative depth indicator: 0.97 (higher = farther)
# Relative depth indicator: 0.95 (higher = farther)
# Relative depth indicator: 0.98 (higher = farther)
# Relative depth indicator: 0.98 (higher = farther)
# Relative depth indicator: 0.98 (higher = farther)
# Relative depth indicator: 0.98 (higher = farther)
# Relative depth indicator: 0.97 (higher = farther)
# Relative depth indicator: 0.97 (higher = farther)
# Relative depth indicator: 0.96 (higher = farther)
# Relative depth indicator: 0.96 (higher = farther)
# Relative depth indicator: 0.96 (higher = farther)
# Relative depth indicator: 0.96 (higher = farther)
# Relative depth indicator: 0.96 (higher = farther)
# Relative depth indicator: 0.97 (higher = farther)
# Relative depth indicator: 0.97 (higher = farther)
# Relative depth indicator: 0.98 (higher = farther)
# Relative depth indicator: 0.98 (higher = farther)
# Relative depth indicator: 0.98 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 349.31 (higher = farther)
# Relative depth indicator: 349.31 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 118.19 (higher = farther)
# Relative depth indicator: 118.19 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 736.68 (higher = farther)
# Relative depth indicator: 736.68 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 368.84 (higher = farther)
# Relative depth indicator: 368.84 (higher = farther)
# Relative depth indicator: 368.84 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 225.62 (higher = farther)
# Relative depth indicator: 225.62 (higher = farther)
# Relative depth indicator: 225.62 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 202.85 (higher = farther)
# Relative depth indicator: 202.85 (higher = farther)
# Relative depth indicator: 1211.97 (higher = farther)
# Relative depth indicator: 1211.97 (higher = farther)
# Relative depth indicator: 1211.97 (higher = farther)
# Relative depth indicator: 1898.82 (higher = farther)
# Relative depth indicator: 1898.82 (higher = farther)
# Relative depth indicator: 609.74 (higher = farther)
# Relative depth indicator: 609.74 (higher = farther)
# Relative depth indicator: 935.26 (higher = farther)
# Relative depth indicator: 935.26 (higher = farther)
# Relative depth indicator: 935.26 (higher = farther)
# Relative depth indicator: 440.46 (higher = farther)
# Relative depth indicator: 668.33 (higher = farther)
# Relative depth indicator: 668.33 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 163.77 (higher = farther)
# Relative depth indicator: 163.77 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 453.49 (higher = farther)
# Relative depth indicator: 453.49 (higher = farther)
# Relative depth indicator: 538.12 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 215.84 (higher = farther)
# Relative depth indicator: 53.08 (higher = farther)
# Relative depth indicator: 53.08 (higher = farther)
# Relative depth indicator: 612.97 (higher = farther)
# Relative depth indicator: 153.99 (higher = farther)
# Relative depth indicator: 153.99 (higher = farther)
# Relative depth indicator: 72.61 (higher = farther)
# Relative depth indicator: 72.61 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 88.90 (higher = farther)
# Relative depth indicator: 88.90 (higher = farther)
# Relative depth indicator: 300.49 (higher = farther)
# Relative depth indicator: 339.53 (higher = farther)
# Relative depth indicator: 339.53 (higher = farther)
# Relative depth indicator: 310.24 (higher = farther)
# Relative depth indicator: 1570.01 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 111.69 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 433.94 (higher = farther)
# Relative depth indicator: 997.09 (higher = farther)
# Relative depth indicator: 997.09 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 193.07 (higher = farther)
# Relative depth indicator: 193.07 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 329.79 (higher = farther)
# Relative depth indicator: 329.79 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1045.92 (higher = farther)
# Relative depth indicator: 1045.92 (higher = farther)
# Relative depth indicator: 954.77 (higher = farther)
# Relative depth indicator: 398.13 (higher = farther)
# Relative depth indicator: 398.13 (higher = farther)
# Relative depth indicator: 974.30 (higher = farther)
# Relative depth indicator: 359.07 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 306.98 (higher = farther)
# Relative depth indicator: 306.98 (higher = farther)
# Relative depth indicator: 899.43 (higher = farther)
# Relative depth indicator: 1560.26 (higher = farther)
# Relative depth indicator: 1560.26 (higher = farther)
# Relative depth indicator: 176.80 (higher = farther)
# Relative depth indicator: 157.26 (higher = farther)
# Relative depth indicator: 157.26 (higher = farther)
# Relative depth indicator: 652.06 (higher = farther)
# Relative depth indicator: 951.53 (higher = farther)
# Relative depth indicator: 951.53 (higher = farther)
# Relative depth indicator: 219.11 (higher = farther)
# Relative depth indicator: 199.58 (higher = farther)
# Relative depth indicator: 199.58 (higher = farther)
# Relative depth indicator: 691.12 (higher = farther)
# Relative depth indicator: 1143.57 (higher = farther)
# Relative depth indicator: 1143.57 (higher = farther)
# Relative depth indicator: 489.28 (higher = farther)
# Relative depth indicator: 1250.99 (higher = farther)
# Relative depth indicator: 1250.99 (higher = farther)
# Relative depth indicator: 1452.82 (higher = farther)
# Relative depth indicator: 1045.94 (higher = farther)
# Relative depth indicator: 1045.94 (higher = farther)
# Relative depth indicator: 235.37 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 0.99 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 219.10 (higher = farther)
# Relative depth indicator: 219.10 (higher = farther)
# Relative depth indicator: 948.28 (higher = farther)
# Relative depth indicator: 730.18 (higher = farther)
# Relative depth indicator: 730.18 (higher = farther)
# Relative depth indicator: 505.57 (higher = farther)
# Relative depth indicator: 486.02 (higher = farther)
# Relative depth indicator: 486.02 (higher = farther)
# Relative depth indicator: 131.22 (higher = farther)
# Relative depth indicator: 274.43 (higher = farther)
# Relative depth indicator: 274.43 (higher = farther)
# Relative depth indicator: 238.64 (higher = farther)
# Relative depth indicator: 238.64 (higher = farther)
# Relative depth indicator: 225.62 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 147.50 (higher = farther)
# Relative depth indicator: 147.50 (higher = farther)
# Relative depth indicator: 1270.55 (higher = farther)
# Relative depth indicator: 866.90 (higher = farther)
# Relative depth indicator: 866.90 (higher = farther)
# Relative depth indicator: 1010.11 (higher = farther)
# Relative depth indicator: 1576.51 (higher = farther)
# Relative depth indicator: 1576.51 (higher = farther)
# Relative depth indicator: 1325.86 (higher = farther)
# Relative depth indicator: 1325.86 (higher = farther)
# Relative depth indicator: 1052.43 (higher = farther)
# Relative depth indicator: 1019.89 (higher = farther)
# Relative depth indicator: 502.31 (higher = farther)
# Relative depth indicator: 502.31 (higher = farther)
# Relative depth indicator: 1342.16 (higher = farther)
# Relative depth indicator: 570.67 (higher = farther)
# Relative depth indicator: 570.67 (higher = farther)
# Relative depth indicator: 1472.37 (higher = farther)
# Relative depth indicator: 1472.37 (higher = farther)
# Relative depth indicator: 1163.12 (higher = farther)
# Relative depth indicator: 945.02 (higher = farther)
# Relative depth indicator: 945.02 (higher = farther)
# Relative depth indicator: 971.07 (higher = farther)
# Relative depth indicator: 958.04 (higher = farther)
# Relative depth indicator: 792.01 (higher = farther)
# Relative depth indicator: 792.01 (higher = farther)
# Relative depth indicator: 814.80 (higher = farther)
# Relative depth indicator: 453.47 (higher = farther)
# Relative depth indicator: 453.47 (higher = farther)
# Relative depth indicator: 961.28 (higher = farther)
# Relative depth indicator: 961.28 (higher = farther)
# Relative depth indicator: 238.62 (higher = farther)
# Relative depth indicator: 206.09 (higher = farther)
# Relative depth indicator: 206.09 (higher = farther)
# Relative depth indicator: 235.39 (higher = farther)
# Relative depth indicator: 1215.21 (higher = farther)
# Relative depth indicator: 486.04 (higher = farther)
# Relative depth indicator: 486.04 (higher = farther)
# Relative depth indicator: 466.51 (higher = farther)
# Relative depth indicator: 466.51 (higher = farther)
# Relative depth indicator: 814.81 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 209.33 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 1.00 (higher = farther)
# Relative depth indicator: 43.33 (higher = farther)
# Relative depth indicator: 1163.12 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 616.25 (higher = farther)
# Relative depth indicator: 616.25 (higher = farther)
# Relative depth indicator: 502.31 (higher = farther)
# Relative depth indicator: 1638.38 (higher = farther)
# Relative depth indicator: 1638.38 (higher = farther)
# Relative depth indicator: 2175.47 (higher = farther)
# Relative depth indicator: 1325.88 (higher = farther)
# Relative depth indicator: 1325.88 (higher = farther)
# Relative depth indicator: 1351.92 (higher = farther)
# Relative depth indicator: 1325.88 (higher = farther)
# Relative depth indicator: 1325.88 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 144.26 (higher = farther)
# Relative depth indicator: 1.03 (higher = farther)
# Relative depth indicator: 215.87 (higher = farther)
# Relative depth indicator: 375.38 (higher = farther)
# Relative depth indicator: 1423.55 (higher = farther)
# Relative depth indicator: 1423.55 (higher = farther)
# Relative depth indicator: 1726.29 (higher = farther)
# Relative depth indicator: 987.36 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 160.54 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 1224.99 (higher = farther)
# Relative depth indicator: 766.01 (higher = farther)
# Relative depth indicator: 857.15 (higher = farther)
# Relative depth indicator: 1804.42 (higher = farther)
# Relative depth indicator: 788.80 (higher = farther)
# Relative depth indicator: 287.50 (higher = farther)
# Relative depth indicator: 909.24 (higher = farther)
# Relative depth indicator: 183.33 (higher = farther)
# Relative depth indicator: 1563.53 (higher = farther)
# Relative depth indicator: 1563.53 (higher = farther)
# Relative depth indicator: 381.89 (higher = farther)
# Relative depth indicator: 1446.35 (higher = farther)
# Relative depth indicator: 352.59 (higher = farther)
# Relative depth indicator: 2621.47 (higher = farther)
# Relative depth indicator: 2094.13 (higher = farther)
# Relative depth indicator: 1781.63 (higher = farther)
# Relative depth indicator: 1999.73 (higher = farther)
# Relative depth indicator: 2595.43 (higher = farther)
# Relative depth indicator: 1410.54 (higher = farther)
# Relative depth indicator: 1410.54 (higher = farther)
# Relative depth indicator: 1889.06 (higher = farther)
# Relative depth indicator: 1358.46 (higher = farther)
# Relative depth indicator: 473.02 (higher = farther)
# Relative depth indicator: 394.90 (higher = farther)
# Relative depth indicator: 147.50 (higher = farther)
# Relative depth indicator: 570.69 (higher = farther)
# Relative depth indicator: 1342.18 (higher = farther)
# Relative depth indicator: 863.67 (higher = farther)
# Relative depth indicator: 1273.82 (higher = farther)
# Relative depth indicator: 1273.82 (higher = farther)
# Relative depth indicator: 495.81 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 209.35 (higher = farther)
# Relative depth indicator: 238.67 (higher = farther)
# Relative depth indicator: 984.11 (higher = farther)
# Relative depth indicator: 870.17 (higher = farther)
# Relative depth indicator: 424.19 (higher = farther)
# Relative depth indicator: 544.64 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 525.12 (higher = farther)
# Relative depth indicator: 863.67 (higher = farther)
# Relative depth indicator: 3028.38 (higher = farther)
# Relative depth indicator: 2683.33 (higher = farther)
# Relative depth indicator: 163.79 (higher = farther)
# Relative depth indicator: 2754.94 (higher = farther)
# Relative depth indicator: 2403.38 (higher = farther)
# Relative depth indicator: 2064.84 (higher = farther)
# Relative depth indicator: 1794.66 (higher = farther)
# Relative depth indicator: 1794.66 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 290.73 (higher = farther)
# Relative depth indicator: 1.01 (higher = farther)
# Relative depth indicator: 1.03 (higher = farther)
# Relative depth indicator: 739.95 (higher = farther)
# Relative depth indicator: 134.48 (higher = farther)
# Relative depth indicator: 215.86 (higher = farther)
# Relative depth indicator: 3617.58 (higher = farther)
# Relative depth indicator: 186.58 (higher = farther)
# Relative depth indicator: 870.18 (higher = farther)
# Relative depth indicator: 313.54 (higher = farther)
# Relative depth indicator: 1947.65 (higher = farther)
# Relative depth indicator: 2419.66 (higher = farther)
# Relative depth indicator: 72.63 (higher = farther)
# Relative depth indicator: 443.74 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 518.61 (higher = farther)
# Relative depth indicator: 447.00 (higher = farther)
# Relative depth indicator: 541.40 (higher = farther)
# Relative depth indicator: 1208.72 (higher = farther)
# Relative depth indicator: 691.14 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 75.89 (higher = farther)
# Relative depth indicator: 352.60 (higher = farther)
# Relative depth indicator: 2468.49 (higher = farther)
# Relative depth indicator: 736.71 (higher = farther)
# Relative depth indicator: 385.15 (higher = farther)
# Relative depth indicator: 2803.77 (higher = farther)
# Relative depth indicator: 2058.33 (higher = farther)
# Relative depth indicator: 2230.85 (higher = farther)
# Relative depth indicator: 2780.98 (higher = farther)
# Relative depth indicator: 2419.66 (higher = farther)
# Relative depth indicator: 4086.32 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 173.54 (higher = farther)
# Relative depth indicator: 883.20 (higher = farther)
# Relative depth indicator: 238.66 (higher = farther)
# Relative depth indicator: 489.32 (higher = farther)
# Relative depth indicator: 1618.88 (higher = farther)
# Relative depth indicator: 2221.09 (higher = farther)
# Relative depth indicator: 1573.30 (higher = farther)
# Relative depth indicator: 1648.17 (higher = farther)
# Relative depth indicator: 905.99 (higher = farther)
# Relative depth indicator: 883.20 (higher = farther)
# Relative depth indicator: 964.58 (higher = farther)
# Relative depth indicator: 79.16 (higher = farther)
# Relative depth indicator: 710.67 (higher = farther)
# Relative depth indicator: 1098.04 (higher = farther)
# Relative depth indicator: 590.23 (higher = farther)
# Relative depth indicator: 687.88 (higher = farther)
# Relative depth indicator: 935.28 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 2260.15 (higher = farther)
# Relative depth indicator: 1381.25 (higher = farther)
# Relative depth indicator: 1485.41 (higher = farther)
# Relative depth indicator: 2247.13 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
# Relative depth indicator: 33.57 (higher = farther)
# Relative depth indicator: 72.63 (higher = farther)
# Relative depth indicator: 665.10 (higher = farther)
# Relative depth indicator: 2767.96 (higher = farther)
# Relative depth indicator: 1491.92 (higher = farther)
# Relative depth indicator: 1228.25 (higher = farther)
# Relative depth indicator: 1293.35 (higher = farther)
# Relative depth indicator: 2211.32 (higher = farther)
# Relative depth indicator: 1244.53 (higher = farther)
# Relative depth indicator: 1846.74 (higher = farther)
# Relative depth indicator: 1065.49 (higher = farther)
# Relative depth indicator: 1.02 (higher = farther)
