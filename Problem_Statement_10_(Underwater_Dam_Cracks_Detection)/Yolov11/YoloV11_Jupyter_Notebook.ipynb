# %%
# !pip uninstall torch -y
# !pip install torch
# Out:
# Found existing installation: torch 2.6.0
# Uninstalling torch-2.6.0:
#   Successfully uninstalled torch-2.6.0
# WARNING: Failed to remove contents in a temporary directory 'C:\Anaconda\Lib\site-packages\~-rch'.
# You can safely remove it manually.
# ...
# WARNING: Ignoring invalid distribution ~orch (C:\Anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~orch (C:\Anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~orch (C:\Anaconda\Lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.6.0 requires torch==2.6.0, but you have torch 2.7.1 which is incompatible.
# torchvision 0.21.0 requires torch==2.6.0, but you have torch 2.7.1 which is incompatible.
#   Using cached torch-2.7.1-cp312-cp312-win_amd64.whl.metadata (28 kB)
# ...
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# ...

# %%
get_ipython().run_line_magic('pip', 'install ultralytics')
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.74  Python-3.12.7 torch-2.6.0+cpu CPU (Intel Core(TM) i5-1035G1 1.00GHz)
# Setup complete  (8 CPUs, 19.7 GB RAM, 166.6/243.7 GB disk)

# %%
pip install --upgrade bottleneck
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: bottleneck in c:\anaconda\lib\site-packages (1.5.0)
# ...
# WARNING: Ignoring invalid distribution ~orch (C:\Anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~orch (C:\Anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~orch (C:\Anaconda\Lib\site-packages)

# %%
pip install --upgrade --user bottleneck
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: bottleneck in c:\anaconda\lib\site-packages (1.5.0)
# ...
# WARNING: Ignoring invalid distribution ~orch (C:\Anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~orch (C:\Anaconda\Lib\site-packages)

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %%
pip install intel-openmp
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~orch (C:\Anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~orch (C:\Anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~orch (C:\Anaconda\Lib\site-packages)

# %%
get_ipython().system('yolo val model=yolo11n.pt data="D:/IIT_Mandi/Problem_Statements/Pending/Problem_Statement_12_(Underwater_Dam_Cracks_Detection)/YoloV11/Dataset/data.yaml"')
# Out:
# Ultralytics 8.3.74 ðŸš€ Python-3.12.7 torch-2.6.0+cpu CPU (Intel Core(TM) i5-1035G1 1.00GHz)
# YOLO11n summary (fused): 238 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
# val: New cache created: D:\IIT_Mandi\Problem_Statements\Pending\Problem_Statement_12_(Underwater_Dam_Cracks_Detection)\YoloV11\Dataset\valid\labels.cache
#                    all        416        624     0.0557      0.176     0.0469     0.0244
#                 person        416        624     0.0557      0.176     0.0469     0.0244
# Speed: 1.7ms preprocess, 101.7ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to runs\detect\val17
# ðŸ’¡ Learn more at https://docs.ultralytics.com/modes/val
# val: Scanning D:\IIT_Mandi\Problem_Statements\Pending\Problem_Statement_12_(Underwater_Dam_Cracks_Detection)\YoloV11\Dataset\valid\labels...:   0%|          | 0/416 [00:00<?, ?it/s]
# ...

# %%
get_ipython().system('yolo train model=yolo11n.pt data="D:/IIT_Mandi/Problem_Statements/Pending/Problem_Statement_12_(Underwater_Dam_Cracks_Detection)/YoloV11/Dataset/data.yaml" epochs=50 imgsz=640')

# %%
get_ipython().system('yolo predict model="C:/Users/Wilfred Auxilian/runs/detect/train17/weights/best.pt" source="C:/Users/Wilfred Auxilian/Downloads/Dam_Crack_Datasets/Dataset_1/dam crack relabel.v1i.yolov11/test/images/155_jpg.rf.660da78aa0fd45c7d960474f968971db.jpg"')
# Out:
# Ultralytics 8.3.74 ðŸš€ Python-3.12.7 torch-2.6.0+cpu CPU (Intel Core(TM) i5-1035G1 1.00GHz)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/1 C:\Users\Wilfred Auxilian\Downloads\Dam_Crack_Datasets\Dataset_1\dam crack relabel.v1i.yolov11\test\images\155_jpg.rf.660da78aa0fd45c7d960474f968971db.jpg: 384x640 (no detections), 96.4ms
# Speed: 2.1ms preprocess, 96.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\predict3
# ðŸ’¡ Learn more at https://docs.ultralytics.com/modes/predict
